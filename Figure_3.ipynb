# %% [markdown]
# <a href="https://colab.research.google.com/github/farihahahmed/wind-power-forecasting-AI-cost-cutting-with-past-power-production-data/blob/main/Figure_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Path to the CSV file
file_path = '/content/drive/MyDrive/HSA/wb_nn7.csv'

# Read the CSV file into a DataFrame
wb_df = pd.read_csv(file_path)

# %%
wb_df
# Out:
#        Unnamed: 0         pred       y_test
# 0           40424     1.654101     0.000000
# 1           40425     1.654101     0.000000
# 2           40426     1.654101     0.000000
# 3           40427     1.654101     0.000000
# 4           40428     1.654101     0.000000
# ...           ...          ...          ...
# 10101       50525  2749.614000  2963.980957
# 10102       50526  1007.799560  1684.353027
# 10103       50527  1365.167700  2201.106934
# 10104       50528  1703.632000  2515.694092
# 10105       50529  1976.626300  2820.466064
#
# [10106 rows x 3 columns]

# %%
wb_df = wb_df.drop('Unnamed: 0', axis=1)

# %%
wb_df
# Out:
#               pred       y_test
# 0         1.654101     0.000000
# 1         1.654101     0.000000
# 2         1.654101     0.000000
# 3         1.654101     0.000000
# 4         1.654101     0.000000
# ...            ...          ...
# 10101  2749.614000  2963.980957
# 10102  1007.799560  1684.353027
# 10103  1365.167700  2201.106934
# 10104  1703.632000  2515.694092
# 10105  1976.626300  2820.466064
#
# [10106 rows x 2 columns]

# %%
# Path to the second CSV file
file_path2 = '/content/drive/MyDrive/HSA/nwb_nn6.csv'

# Read the second CSV file into a DataFrame
nwb_df = pd.read_csv(file_path2)

# %%
nwb_df
# Out:
#        Unnamed: 0         pred       y_test
# 0           40423    10.521995     0.000000
# 1           40424    10.521995     0.000000
# 2           40425    10.521995     0.000000
# 3           40426    10.521995     0.000000
# 4           40427    10.521995     0.000000
# ...           ...          ...          ...
# 10101       50524  3391.522000  2963.980957
# 10102       50525  2864.622000  1684.353027
# 10103       50526  1639.380000  2201.106934
# 10104       50527  2134.171400  2515.694092
# 10105       50528  2435.388000  2820.466064
#
# [10106 rows x 3 columns]

# %%
nwb_df = nwb_df.drop('Unnamed: 0', axis=1)

# %%
nwb_df
# Out:
#               pred       y_test
# 0        10.521995     0.000000
# 1        10.521995     0.000000
# 2        10.521995     0.000000
# 3        10.521995     0.000000
# 4        10.521995     0.000000
# ...            ...          ...
# 10101  3391.522000  2963.980957
# 10102  2864.622000  1684.353027
# 10103  1639.380000  2201.106934
# 10104  2134.171400  2515.694092
# 10105  2435.388000  2820.466064
#
# [10106 rows x 2 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

start = 90+144+144+144+144+144
end = 120+144+144+144+144+144

x_axis = np.linspace(15, 20, num=30)

# Plotting the first graph: 'Weather-based prediction'
plt.plot(x_axis, wb_df['pred'][start:end], label='Weather-based prediction', color='red')

# Plotting the second graph: 'Non-weather-based prediction'
plt.plot(x_axis, nwb_df['pred'][start:end], label='Non-weather-based prediction', color='blue')

# Plotting the third graph: 'Actual Power Output'
plt.plot(x_axis, wb_df['y_test'][start:end], label='Actual Power Output', color='green')

# Customize the axes labels
plt.xlabel('Hour of the day')
plt.ylabel('Power generated in that hour (kW)')


# Display the legend
plt.legend()

# Show the overlaid graphs
plt.show()
